# %% [markdown]
#    <H1> My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Akshay Viswanath P**
# Data Scientist

# %% [markdown]
# _Data scientist has interested me as it has no limitations or boundaries considering any field. This involves a creative thinking and the solution is not always going to be the same._

# %% [markdown]
# <H3> Addition of two numbers

# %%
5+6
# Out:
# 11

# %% [markdown]
# |Row 1|Row2|
# |:---|:---:|
# |One|Two|
#
#  ~~Strikethrough~~ [IBM Skills Build](https://skillsbuild.org/)
